# %%
import sys, os
os.environ["NYT_API_KEY"] = "D3rEmsx7BLB57Hq5BhGBGY0FAukEMhoX"
sys.path.append(os.getcwd())
sys.path.append(os.path.join(os.getcwd(), "src"))

from run_pipeline import run_pipeline_nyt
run_pipeline_nyt()
# Out:
# [NYT] Events:
#   event_id                              name event_date      start        end  \
# 0  AFG2009          Afghanistan surge (2009) 2009-12-01 2009-11-17 2009-12-29
# 1  PAK2011         Bin Laden raid (May 2011) 2011-05-02 2011-04-18 2011-05-30
# 2  LBY2011         Libya intervention (2011) 2011-03-19 2011-03-05 2011-04-16
# 3  SYR2013     Syria chemical weapons crisis 2013-08-21 2013-08-07 2013-09-18
# 4  IRQ2014  ISIS airstrikes announced (2014) 2014-09-10 2014-08-27 2014-10-08
# 5  IRQ2016            Mosul offensive (2016) 2016-10-17 2016-10-03 2016-11-14
# 6  SYR2017     US strikes on Syria (Shayrat) 2017-04-07 2017-03-24 2017-05-05
# 7  SYR2018   Douma chemical attacks response 2018-04-14 2018-03-31 2018-05-12
#
#   support_level
# 0          high
# 1          high
# 2          high
# 3           low
# 4          high
# 5          high
# 6           low
# 7           low
# [NYT] Collecting AFG2009 with query: 'Afghanistan AND surge'
# ...

# %%
import post_pipeline_outputs
post_pipeline_outputs.run_all_outputs()
# Out:
# [tables] Saved tables\nyt_counts_summary.csv
# [tables] Saved tables\nyt_counts_summary.tex
# [tables] Saved tables\nyt_prepost_means_by_event.csv
# [tables] Saved tables\nyt_prepost_means_by_event.tex
# [tables] Saved tables\nyt_prepost_means_by_domain_top10.csv
# [tables] Saved tables\nyt_prepost_means_by_domain_top10.tex
# [warn] Regression for fk_grade failed: module 'src.analyze' has no attribute 'run_prepost_fe_regression'
# [warn] Regression for avg_rarity failed: module 'src.analyze' has no attribute 'run_prepost_fe_regression'
# [warn] Regression for rare_share failed: module 'src.analyze' has no attribute 'run_prepost_fe_regression'
# [plots] Saved figures\nyt_fk_grade_prepost_by_event_manual.png
# [plots] Saved figures\nyt_fk_grade_prepost_by_domain_top8_manual.png
# [plots] Saved figures\nyt_avg_rarity_prepost_by_event_manual.png
# [plots] Saved figures\nyt_avg_rarity_prepost_by_domain_top8_manual.png
# [plots] Saved figures\nyt_rare_share_prepost_by_event_manual.png
# ...
